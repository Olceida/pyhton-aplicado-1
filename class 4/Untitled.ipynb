# %%
import pandas as pd

# %%
df = pd.read_excel('youtube_mexico.xlsx', parse_dates=['trending_date'])

# %%
df
# Out:
#           video_id trending_date  \
# 0      SbOwzAl9ZfQ      17.14.11
# 1      klOV6Xh-DnI      17.14.11
# 2      6L2ZF7Qzsbk      17.14.11
# 3      hcY52MFWMDM      17.14.11
# 4      _OXDcGPVAa4      17.14.11
# ...            ...           ...
# 40446  r63VBOagGAo      18.14.06
# 40447  i7r_kMbyngk      18.14.06
# 40448  _jnwjdMe3Zo      18.14.06
# 40449  pAH9omNAWA4      18.14.06
# 40450  dj5Z4jTE3-c      18.14.06
#
#                                                    title  \
# 0                         CapÃ­tulo 12 | MasterChef 2017
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2               LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3       Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4               DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                  ...
# 40446  Shawn Mendes x Portugal (FPF Official World Cu...
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...
# ...

# %%
df[df['publish_time']>'2018-06-13']
# Out:
#           video_id trending_date  \
# 40098  WUIVD_EXlno      18.13.06
# 40099  1it5N5prC2o      18.13.06
# 40100  7Mo7FzqlQTE      18.13.06
# 40101  p7AoSXscrqU      18.13.06
# 40102  90VkNbc2FYM      18.13.06
# ...            ...           ...
# 40446  r63VBOagGAo      18.14.06
# 40447  i7r_kMbyngk      18.14.06
# 40448  _jnwjdMe3Zo      18.14.06
# 40449  pAH9omNAWA4      18.14.06
# 40450  dj5Z4jTE3-c      18.14.06
#
#                                                    title  \
# 40098         Tercer Debate Presidencial #Elecciones2018
# 40099   Tercer Debate Presidencial 2018 completo en vivo
# 40100  Debate Presidencial #3 en MÃ©rida, Yucatan - C...
# 40101      El seÃ±or de los cielos 6 cap 26 parte 2/7 HD
# 40102                 POST-DEBATITLÃN DEL TERCER DEBATE
# ...                                                  ...
# 40446  Shawn Mendes x Portugal (FPF Official World Cu...
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...
# ...

# %%
df[(df['channel_title']== 'DrossRotzank') & (df['publish_time']>'2018-02-13 13:00:00') & (df['publish_time']<'2018-08-13 14:00:00')]
# Out:
#           video_id trending_date  \
# 19554  vF_RR9iL07w      18.22.02
# 19779  vF_RR9iL07w      18.23.02
# 19947  fGs4hNIJoqs      18.24.02
# 20175  fGs4hNIJoqs      18.25.02
# 20346  2qSSF-vvO2c      18.26.02
# ...            ...           ...
# 38914  IFGxyWnRNq0      18.06.06
# 39370  i20fQDHYlNI      18.09.06
# 39577  i20fQDHYlNI      18.10.06
# 39796  i20fQDHYlNI      18.11.06
# 40276  SeRbJnGdYJM      18.14.06
#
#                                                    title channel_title  \
# 19554                       EL MISTERIO DEL CANAL INSIDE  DrossRotzank
# 19779                       EL MISTERIO DEL CANAL INSIDE  DrossRotzank
# 19947                               El misterio de Alexa  DrossRotzank
# 20175                               El misterio de Alexa  DrossRotzank
# 20346  Las 7 cosas mÃ¡s mÃ³rbidas (y aterradoras) enc...  DrossRotzank
# ...                                                  ...           ...
# ...

# %%
dross = df[(df['channel_title']== 'DrossRotzank') & (df['publish_time']>'2018-02-13 13:00:00') & (df['publish_time']<'2018-08-13 14:00:00')]

# %%
dross.describe()
# Out:
#        category_id         views          likes      dislikes  comment_count
# count         67.0  6.700000e+01      67.000000     67.000000      67.000000
# mean          24.0  1.474783e+06  111288.432836   4665.104478   16855.194030
# std            0.0  6.757742e+05   41493.216620   2590.002037    9365.852928
# min           24.0  3.711070e+05   36605.000000   1221.000000    5015.000000
# 25%           24.0  7.843205e+05   80590.500000   2431.000000   10342.500000
# 50%           24.0  1.484467e+06  113677.000000   4338.000000   15120.000000
# 75%           24.0  1.935740e+06  141018.000000   6356.500000   20338.000000
# max           24.0  3.057575e+06  244692.000000  10724.000000   57261.000000

# %%
dross['likes']
# Out:
# 19554     87875
# 19779    116559
# 19947    131837
# 20175    172644
# 20346    104122
#           ...
# 38914    244692
# 39370     79054
# 39577    144260
# 39796    152242
# 40276     58092
# Name: likes, Length: 67, dtype: int64

# %%
dross['publish_time']
# Out:
# 19554   2018-02-21 20:00:02+00:00
# 19779   2018-02-21 20:00:02+00:00
# 19947   2018-02-23 17:59:53+00:00
# 20175   2018-02-23 17:59:53+00:00
# 20346   2018-02-25 17:05:52+00:00
#                    ...
# 38914   2018-06-04 02:59:18+00:00
# 39370   2018-06-09 00:00:03+00:00
# 39577   2018-06-09 00:00:03+00:00
# 39796   2018-06-09 00:00:03+00:00
# 40276   2018-06-14 02:19:59+00:00
# Name: publish_time, Length: 67, dtype: datetime64[ns, UTC]

# %%
ts = pd.Series(dross['likes'], index = dross['publish_time'])
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:xlabel='publish_time'>

# %%
dross[['likes','dislikes']].plot()
# Out:
# <AxesSubplot:>

# %%
dross.loc['2018-1':'2018:2','likes'].plot()
# Out:
# <AxesSubplot:>

# %%
df.index = pd.to_datetime(df['publish_time'])

# %%
df
# Out:
#                               video_id trending_date  \
# publish_time
# 2017-11-13 06:06:22+00:00  SbOwzAl9ZfQ      17.14.11
# 2017-11-13 05:11:58+00:00  klOV6Xh-DnI      17.14.11
# 2017-11-13 17:00:02+00:00  6L2ZF7Qzsbk      17.14.11
# 2017-11-13 03:47:10+00:00  hcY52MFWMDM      17.14.11
# 2017-11-13 19:17:48+00:00  _OXDcGPVAa4      17.14.11
# ...                                ...           ...
# 2018-06-13 13:11:56+00:00  r63VBOagGAo      18.14.06
# 2018-06-13 01:15:08+00:00  i7r_kMbyngk      18.14.06
# 2018-06-13 15:08:53+00:00  _jnwjdMe3Zo      18.14.06
# 2018-06-13 02:22:33+00:00  pAH9omNAWA4      18.14.06
# 2018-06-13 19:01:52+00:00  dj5Z4jTE3-c      18.14.06
#
#                                                                        title  \
# publish_time
# 2017-11-13 06:06:22+00:00                     CapÃ­tulo 12 | MasterChef 2017
# 2017-11-13 05:11:58+00:00  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='publish_time'>

# %%
df.index.year
# Out:
# Int64Index([2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017,
#             ...
#             2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018],
#            dtype='int64', name='publish_time', length=40451)

# %%
df.index.month
# Out:
# Int64Index([11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#             ...
#              6,  6,  6,  6,  5,  6,  6,  6,  6,  6],
#            dtype='int64', name='publish_time', length=40451)

# %%
df["2017-1-1":"2017-2-2"].plot()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-f9981832f643> in <module>
# ----> 1 df["2017-1-1":"2017-2-2"].plot()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2883             # either we have a slice or we have a string that can be converted
#    2884             #  to a slice for partial-string date indexing
# -> 2885             return self._slice(indexer, axis=0)
#    2886
#    2887         # Do we have a (boolean) DataFrame?
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis)
#    3555         Slicing with this method is *always* positional.
#    3556         """
# -> 3557         assert isinstance(slobj, slice), type(slobj)
#    3558         axis = self._get_block_manager_axis(axis)
#    3559         result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#
# ...

# %%
df[df['channel_title']== 'DrossRotzank'].plot(x='publish_time', y='likes', grid=True, figsize=(15,3))
# Out:
# <AxesSubplot:xlabel='publish_time'>
