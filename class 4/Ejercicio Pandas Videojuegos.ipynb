# %%
import pandas as pd

# %%
df = pd.read_excel("videojuegos.xlsx", parse_dates=['Year'])

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
# DF los 150 videojuegos mas vedidos por nintendo
df[df['Publisher']=='Nintendo'].head(150)
# Out:
#      Rank                                   Name Platform    Year  \
# 0       1                             Wii Sports      Wii  2006.0
# 1       2                      Super Mario Bros.      NES  1985.0
# 2       3                         Mario Kart Wii      Wii  2008.0
# 3       4                      Wii Sports Resort      Wii  2009.0
# 4       5               Pokemon Red/Pokemon Blue       GB  1996.0
# ..    ...                                    ...      ...     ...
# 535   536  Professor Layton and the Last Specter       DS  2009.0
# 536   537                     Monster Hunter Tri      3DS  2011.0
# 545   546                            Mario Paint     SNES  1992.0
# 547   548                     Pok̩mon Stadium 2      N64  2000.0
# 548   549                                Metroid      NES  1986.0
#
#             Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0          Sports  Nintendo     41.49     29.02      3.77         8.46
# ...

# %%
# DF los 50 videojuegos mas vedidos por Nintendo a partir del anio 2011
df[(df['Publisher']=='Nintendo') & (df['Year']>=2011)].sort_values(['Year'], ascending=False).head(50)
# Out:
#         Rank                                               Name Platform  \
# 6588    6590        Mario & Sonic at the Rio 2016 Olympic Games     WiiU
# 12954  12956                                    Culdcept Revolt      3DS
# 5288    5290                                     Star Fox: Zero     WiiU
# 4261    4263        Mario & Sonic at the Rio 2016 Olympic Games      3DS
# 2448    2450                              Kirby: Planet Robobot      3DS
# 2212    2214          The Legend of Zelda: Twilight Princess HD     WiiU
# 11010  11012                                 Disney Art Academy      3DS
# 14301  14304                    Metroid Prime: Federation Force      3DS
# 14968  14971                                     Teddy Together      3DS
# 4658    4660                                    Hyrule Warriors      3DS
# 1850    1852              The Legend of Zelda: Tri Force Heroes      3DS
# 4400    4402                           Mario Tennis Ultra Smash     WiiU
# ...

# %%
df[df['Name'].str.contains('Star Wars' , na=False)]
# Out:
#         Rank                                             Name Platform  \
# 92        93                     Star Wars Battlefront (2015)      PS4
# 150      151                LEGO Star Wars: The Complete Saga      Wii
# 212      213                LEGO Star Wars: The Complete Saga       DS
# 352      353                           Star Wars: Battlefront      PS2
# 357      358                        Star Wars: Battlefront II      PS2
# ...      ...                                              ...      ...
# 14529  14532                Star Wars: The Force Unleashed II       PC
# 14752  14755        Star Wars The Clone Wars: Republic Heroes       PC
# 14919  14922  Star Wars: Empire at War - Forces of Corruption       PC
# 15745  15748          LEGO Star Wars II: The Original Trilogy       PC
# 15787  15790                   LEGO Star Wars: The Video Game       PC
#
#          Year     Genre          Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df[df['Name'].str.contains('Star Wars', na=False)].describe()
# Out:
#                Rank         Year    NA_Sales    EU_Sales    JP_Sales  \
# count    123.000000   122.000000  123.000000  123.000000  123.000000
# mean    4673.869919  2006.491803    0.619268    0.332358    0.006829
# std     4127.919168     4.936365    0.692724    0.440588    0.027231
# min       93.000000  1994.000000    0.000000    0.000000    0.000000
# 25%     1270.000000  2003.000000    0.125000    0.060000    0.000000
# 50%     3667.000000  2006.000000    0.380000    0.170000    0.000000
# 75%     6943.500000  2010.000000    0.925000    0.445000    0.000000
# max    15790.000000  2016.000000    3.660000    3.290000    0.220000
#
#        Other_Sales  Global_Sales
# count   123.000000    123.000000
# mean      0.104228      1.063008
# std       0.167077      1.235048
# min       0.000000      0.020000
# 25%       0.020000      0.235000
# 50%       0.040000      0.550000
# 75%       0.105000      1.490000
# max       1.230000      7.670000

# %%
df[df['Name'].str.contains('Mario ', na=False)].to_excel('Mario.xlsx', index=False)
