# %%
import pandas as pd

# %%
df = pd.read_excel("youtube_mexico.xlsx")

# %%
df
# Out:
#           video_id trending_date  \
# 0      SbOwzAl9ZfQ      17.14.11
# 1      klOV6Xh-DnI      17.14.11
# 2      6L2ZF7Qzsbk      17.14.11
# 3      hcY52MFWMDM      17.14.11
# 4      _OXDcGPVAa4      17.14.11
# ...            ...           ...
# 40446  r63VBOagGAo      18.14.06
# 40447  i7r_kMbyngk      18.14.06
# 40448  _jnwjdMe3Zo      18.14.06
# 40449  pAH9omNAWA4      18.14.06
# 40450  dj5Z4jTE3-c      18.14.06
#
#                                                    title  \
# 0                         CapÃ­tulo 12 | MasterChef 2017
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2               LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3       Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4               DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                  ...
# 40446  Shawn Mendes x Portugal (FPF Official World Cu...
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...
# ...

# %%
df.head(3)
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
#
#                channel_title  category_id              publish_time  \
# 0            MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1   Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2  El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  310130   4182       361
# 1                                    La Voz Mexico 7  104972    271       174
# 2  Chumel Torres|"El Pulso de la Republica"|"noti...  136064  10105       266
#
# ...

# %%
df.tail(3)
# Out:
#           video_id trending_date  \
# 40448  _jnwjdMe3Zo      18.14.06
# 40449  pAH9omNAWA4      18.14.06
# 40450  dj5Z4jTE3-c      18.14.06
#
#                                                    title   channel_title  \
# 40448  Maire usa una blusa kawaiii Â¿adorable o ridÃ­...  Historias Wink
# 40449       La Jefa del CampeÃ³n - CapÃ­tulo 2 Parte 3/4       Tele Time
# 40450  Â¿POR QUÃ‰ SHANKS ES TAN RESPETADO POR TODOS E...     GolD Nakama
#
#        category_id              publish_time  \
# 40448           24  2018-06-13T15:08:53.000Z
# 40449           22  2018-06-13T02:22:33.000Z
# 40450           24  2018-06-13T19:01:52.000Z
#
#                                                     tags   views  likes  \
# 40448  maire|"maire vs el internet"|"maire vs interne...   14067    538
# 40449                                             [none]   22898     94
# 40450                                             [none]  108936   5398
#
#        dislikes  comment_count  \
# ...

# %%
df['title']
# Out:
# 0                           CapÃ­tulo 12 | MasterChef 2017
# 1        ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2                 LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3         Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4                 DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#                                ...
# 40446    Shawn Mendes x Portugal (FPF Official World Cu...
# 40447    AMLO llegÃ³ con su esposa al Tercer Debate en ...
# 40448    Maire usa una blusa kawaiii Â¿adorable o ridÃ­...
# 40449         La Jefa del CampeÃ³n - CapÃ­tulo 2 Parte 3/4
# 40450    Â¿POR QUÃ‰ SHANKS ES TAN RESPETADO POR TODOS E...
# Name: title, Length: 40451, dtype: object

# %%
df[['title','channel_title']]
# Out:
#                                                    title  \
# 0                         CapÃ­tulo 12 | MasterChef 2017
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2               LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3       Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4               DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                  ...
# 40446  Shawn Mendes x Portugal (FPF Official World Cu...
# 40447  AMLO llegÃ³ con su esposa al Tercer Debate en ...
# 40448  Maire usa una blusa kawaiii Â¿adorable o ridÃ­...
# 40449       La Jefa del CampeÃ³n - CapÃ­tulo 2 Parte 3/4
# 40450  Â¿POR QUÃ‰ SHANKS ES TAN RESPETADO POR TODOS E...
#
#                    channel_title
# 0                MasterChef 2017
# 1       Micky Contreras Martinez
# 2      El Pulso De La RepÃºblica
# 3                       Casanare
# 4                          Musas
# ...                          ...
# 40446           FPFutebolOficial
# ...

# %% [markdown]
# 1) Obtener todos los videos publicados por Dross. El canal de Dross lleva por nombre DrossRotzank

# %%
df[df['channel_title']== 'DrossRotzank']
# Out:
#           video_id trending_date  \
# 9      cOJ68MQm2ac      17.14.11
# 1202   1YAp1EftWE4      17.20.11
# 1415   1YAp1EftWE4      17.21.11
# 3996   RX8j40qQKJA      17.04.12
# 4200   RX8j40qQKJA      17.05.12
# ...            ...           ...
# 38914  IFGxyWnRNq0      18.06.06
# 39370  i20fQDHYlNI      18.09.06
# 39577  i20fQDHYlNI      18.10.06
# 39796  i20fQDHYlNI      18.11.06
# 40276  SeRbJnGdYJM      18.14.06
#
#                                                    title channel_title  \
# 9      TOP: Los 7 libros infantiles mÃ¡s perturbadore...  DrossRotzank
# 1202   Los 7 himnos nacionales mÃ¡s Ã©picos de la his...  DrossRotzank
# 1415   Los 7 himnos nacionales mÃ¡s Ã©picos de la his...  DrossRotzank
# 3996   TOP: LOS 7 TUTORIALES MÃS ABOMINABLES DE LA D...  DrossRotzank
# 4200   TOP: LOS 7 TUTORIALES MÃS ABOMINABLES DE LA D...  DrossRotzank
# ...                                                  ...           ...
# ...

# %%
type(df[df['channel_title']== 'DrossRotzank'])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 2) Ordenar los videos de Dross por numero de visitas

# %%
df[df['channel_title']== 'DrossRotzank'].sort_values('views', ascending= False)
# Out:
#           video_id trending_date  \
# 23532  Qy5Y8CgBnw0      18.14.03
# 38914  IFGxyWnRNq0      18.06.06
# 7259   2u1dfk10QQk      17.20.12
# 17772  EIzfrC79bqY      18.13.02
# 23336  Qy5Y8CgBnw0      18.13.03
# ...            ...           ...
# 26543  fCo40MMH12s      18.29.03
# 34109  ruI31gDGGno      18.12.05
# 34526  GNgcFLg2hbQ      18.14.05
# 30324  RdPNtKfF8fs      18.23.04
# 29919  QC09eSkl6gI      18.21.04
#
#                                                    title channel_title  \
# 23532  Las 7 cosas que nunca jamÃ¡s debes buscar en G...  DrossRotzank
# 38914                             El Sol ha desaparecido  DrossRotzank
# 7259                      DEAR DAVID 4: EL FIN SE ACERCA  DrossRotzank
# 17772                            Dear David 5: Â¿el fin?  DrossRotzank
# 23336  Las 7 cosas que nunca jamÃ¡s debes buscar en G...  DrossRotzank
# ...                                                  ...           ...
# ...

# %%
df[df['channel_title']== 'DrossRotzank'].sort_values('views', ascending= False).hist(['likes'])
# Out:
# array([[<AxesSubplot:title={'center':'likes'}>]], dtype=object)

# %%
df[df['channel_title']== 'DrossRotzank'].sort_values('views', ascending= False).hist(['views'], orientation='horizontal')
# Out:
# array([[<AxesSubplot:title={'center':'views'}>]], dtype=object)

# %% [markdown]
# 4) Con los videos ya ordenados por visitas, mostrar solo aquellos que tengan al menos 100,000 likes

# %%
df[(df['channel_title']== 'DrossRotzank') & (df['likes']>=100000)].sort_values('views', ascending= False)
# Out:
#           video_id trending_date  \
# 23532  Qy5Y8CgBnw0      18.14.03
# 38914  IFGxyWnRNq0      18.06.06
# 7259   2u1dfk10QQk      17.20.12
# 17772  EIzfrC79bqY      18.13.02
# 23336  Qy5Y8CgBnw0      18.13.03
# ...            ...           ...
# 22336  zAG1pfAlHT8      18.08.03
# 9197   rmS3O5IHvzE      17.30.12
# 37677  7s6Wwr8Xksk      18.31.05
# 6795   2u1dfk10QQk      17.18.12
# 38409  IFGxyWnRNq0      18.04.06
#
#                                                    title channel_title  \
# 23532  Las 7 cosas que nunca jamÃ¡s debes buscar en G...  DrossRotzank
# 38914                             El Sol ha desaparecido  DrossRotzank
# 7259                      DEAR DAVID 4: EL FIN SE ACERCA  DrossRotzank
# 17772                            Dear David 5: Â¿el fin?  DrossRotzank
# 23336  Las 7 cosas que nunca jamÃ¡s debes buscar en G...  DrossRotzank
# ...                                                  ...           ...
# ...

# %%
df[(df['channel_title']== 'DrossRotzank') & (df['likes']>=100000)].sort_values('views', ascending= False).head()
# Out:
#           video_id trending_date  \
# 23532  Qy5Y8CgBnw0      18.14.03
# 38914  IFGxyWnRNq0      18.06.06
# 7259   2u1dfk10QQk      17.20.12
# 17772  EIzfrC79bqY      18.13.02
# 23336  Qy5Y8CgBnw0      18.13.03
#
#                                                    title channel_title  \
# 23532  Las 7 cosas que nunca jamÃ¡s debes buscar en G...  DrossRotzank
# 38914                             El Sol ha desaparecido  DrossRotzank
# 7259                      DEAR DAVID 4: EL FIN SE ACERCA  DrossRotzank
# 17772                            Dear David 5: Â¿el fin?  DrossRotzank
# 23336  Las 7 cosas que nunca jamÃ¡s debes buscar en G...  DrossRotzank
#
#        category_id              publish_time  \
# 23532           24  2018-03-11T19:33:29.000Z
# 38914           24  2018-06-04T02:59:18.000Z
# 7259            24  2017-12-18T00:31:33.000Z
# 17772           24  2018-02-11T18:00:01.000Z
# 23336           24  2018-03-11T19:33:29.000Z
#
# ...

# %%
df[(df['channel_title']== 'DrossRotzank') & (df['likes']>=100000)].sort_values('views', ascending= False).describe()
# Out:
#        category_id         views          likes      dislikes  comment_count
# count         65.0  6.500000e+01      65.000000     65.000000      65.000000
# mean          24.0  1.859053e+06  137542.261538   5652.015385   21803.984615
# std            0.0  4.660868e+05   32733.285493   2575.175003   10327.080142
# min           24.0  7.602040e+05  100509.000000   1659.000000    5980.000000
# 25%           24.0  1.520457e+06  114864.000000   3701.000000   15449.000000
# 50%           24.0  1.843202e+06  130737.000000   4919.000000   18954.000000
# 75%           24.0  2.187761e+06  147004.000000   7175.000000   25188.000000
# max           24.0  3.057575e+06  244692.000000  13075.000000   57261.000000

# %% [markdown]
# 1) Obtener todos los videos publicados por MasterChef. El canal de Dross lleva por nombre  MasterChef 2017

# %%
df[df['channel_title'] == "MasterChef 2017"]
# Out:
#          video_id trending_date  \
# 0     SbOwzAl9ZfQ      17.14.11
# 262   SbOwzAl9ZfQ      17.15.11
# 679   vVioMPhM3NE      17.17.11
# 897   eWhpTWkUpIU      17.18.11
# 1371  WG72cgkEHUY      17.20.11
# 1403  WG72cgkEHUY      17.21.11
# 1646  WG72cgkEHUY      17.22.11
# 2639  kEY-b0Lmz3k      17.27.11
# 2799  Dnnqh-0Cpy4      17.28.11
# 3061  Dnnqh-0Cpy4      17.29.11
# 4047  b1YmphwIF-I      17.04.12
# 4197  MBKUkjPo7lQ      17.05.12
# 4445  MBKUkjPo7lQ      17.06.12
# 4740  MBKUkjPo7lQ      17.07.12
# 4842  5uH4HEF0J4I      17.08.12
# 5022  Y3cxyV9P3vc      17.09.12
# 5322  Y3cxyV9P3vc      17.10.12
# 5399  HvOO97FuP7M      17.11.12
# 5599  HvOO97FuP7M      17.12.12
# 5838  HvOO97FuP7M      17.13.12
# 6165  HyVI4D_RK1o      17.14.12
# 6322  MB1oLZqYgWc      17.15.12
# 6820  G49Yho0IU9g      17.18.12
# 6999  pDnd662hN2Q      17.19.12
# 7253  pDnd662hN2Q      17.20.12
# 7726  ZCgF_GcIps0      17.22.12
#
# ...

# %% [markdown]
# 2) Ordenar los videos de MC  por numero de visitas

# %%
df[df['channel_title'] == "MasterChef 2017"].sort_values('views', ascending=False)
# Out:
#          video_id trending_date  \
# 7253  pDnd662hN2Q      17.20.12
# 6999  pDnd662hN2Q      17.19.12
# 5838  HvOO97FuP7M      17.13.12
# 4740  MBKUkjPo7lQ      17.07.12
# 4445  MBKUkjPo7lQ      17.06.12
# 5599  HvOO97FuP7M      17.12.12
# 3061  Dnnqh-0Cpy4      17.29.11
# 262   SbOwzAl9ZfQ      17.15.11
# 1646  WG72cgkEHUY      17.22.11
# 4197  MBKUkjPo7lQ      17.05.12
# 2799  Dnnqh-0Cpy4      17.28.11
# 1403  WG72cgkEHUY      17.21.11
# 0     SbOwzAl9ZfQ      17.14.11
# 4047  b1YmphwIF-I      17.04.12
# 5322  Y3cxyV9P3vc      17.10.12
# 6820  G49Yho0IU9g      17.18.12
# 5399  HvOO97FuP7M      17.11.12
# 5022  Y3cxyV9P3vc      17.09.12
# 7726  ZCgF_GcIps0      17.22.12
# 4842  5uH4HEF0J4I      17.08.12
# 679   vVioMPhM3NE      17.17.11
# 6322  MB1oLZqYgWc      17.15.12
# 6165  HyVI4D_RK1o      17.14.12
# 1371  WG72cgkEHUY      17.20.11
# 897   eWhpTWkUpIU      17.18.11
# 2639  kEY-b0Lmz3k      17.27.11
#
# ...

# %% [markdown]
# Con los videos ya ordenados por visitas, mostrar solo aquellos que tengan al menos 1000 dislikes

# %%
df[(df['channel_title'] == "MasterChef 2017") & (df['dislikes']>=1000)].sort_values('views', ascending=False)
# Out:
#          video_id trending_date                           title  \
# 7253  pDnd662hN2Q      17.20.12    Gran Final | MasterChef 2017
# 6999  pDnd662hN2Q      17.19.12    Gran Final | MasterChef 2017
# 5838  HvOO97FuP7M      17.13.12  CapÃ­tulo 16 | MasterChef 2017
# 5599  HvOO97FuP7M      17.12.12  CapÃ­tulo 16 | MasterChef 2017
#
#         channel_title  category_id              publish_time  \
# 7253  MasterChef 2017           24  2017-12-18T06:21:48.000Z
# 6999  MasterChef 2017           24  2017-12-18T06:21:48.000Z
# 5838  MasterChef 2017           24  2017-12-11T04:38:46.000Z
# 5599  MasterChef 2017           24  2017-12-11T04:38:46.000Z
#
#                                                    tags    views  likes  \
# 7253  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  1277912  14216
# 6999  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  1016602  12364
# 5838  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...   920877   8561
# ...

# %% [markdown]
# Con los videos ya ordenados por visitas, mostrar solo aquellos que tengan al menos 1000 dislikes, y que ademas tengan por lo menos 1,000,000 de vistas

# %%
df[(df['channel_title'] == "MasterChef 2017") & (df['dislikes']>=1000) & (df['views']>=1000000)].sort_values('views', ascending=False)
# Out:
#          video_id trending_date                         title  \
# 7253  pDnd662hN2Q      17.20.12  Gran Final | MasterChef 2017
# 6999  pDnd662hN2Q      17.19.12  Gran Final | MasterChef 2017
#
#         channel_title  category_id              publish_time  \
# 7253  MasterChef 2017           24  2017-12-18T06:21:48.000Z
# 6999  MasterChef 2017           24  2017-12-18T06:21:48.000Z
#
#                                                    tags    views  likes  \
# 7253  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  1277912  14216
# 6999  MasterChef Junior 2017|"TV Azteca"|"recetas"|"...  1016602  12364
#
#       dislikes  comment_count                                  thumbnail_link  \
# 7253      1778           4432  https://i.ytimg.com/vi/pDnd662hN2Q/default.jpg
# 6999      1556           3919  https://i.ytimg.com/vi/pDnd662hN2Q/default.jpg
#
#       comments_disabled  ratings_disabled  video_error_or_removed  \
# ...

# %%
df[(df['channel_title'] == "MasterChef 2017") & (df['dislikes']>=1000) & (df['views']>=1000000)].sort_values('views', ascending=False).to_excel('MC2017.xlsx', index=False)

# %%
df[(df['channel_title'] == "MasterChef 2017") & (df['dislikes']>=1000) & (df['views']>=1000000)].sort_values('views', ascending=False).hist(['likes'])
# Out:
# array([[<AxesSubplot:title={'center':'likes'}>]], dtype=object)

# %%
lista = ['A',2,'C',4,'E',6,'G']
lista
# Out:
# ['A', 2, 'C', 4, 'E', 6, 'G']

# %%
miDiccionario = {
    'Nombres': [pd.NaT,2,'C',4,'E',6,'G'],
    'Edades': [11,12,13,14,pd.NaT,16,17],
    'Nacionalidad': ['MX','MX','MX','MX','MX',pd.NaT,'MX']
    
}

# %%
miDataFrame = pd.DataFrame(miDiccionario)

# %%
miDataFrame
# Out:
#   Nombres Edades Nacionalidad
# 0     NaT     11           MX
# 1       2     12           MX
# 2       C     13           MX
# 3       4     14           MX
# 4       E    NaT           MX
# 5       6     16          NaT
# 6       G     17           MX

# %%
miDataFrame.drop(columns=['Edades'])
# Out:
#   Nombres Nacionalidad
# 0     NaT           MX
# 1       2           MX
# 2       C           MX
# 3       4           MX
# 4       E           MX
# 5       6          NaT
# 6       G           MX

# %%
miDataFrame.dropna()
# Out:
#   Nombres Edades Nacionalidad
# 1       2     12           MX
# 2       C     13           MX
# 3       4     14           MX
# 6       G     17           MX

# %%
miDataFrame.dropna(subset=['Nombres'])
# Out:
#   Nombres Edades Nacionalidad
# 1       2     12           MX
# 2       C     13           MX
# 3       4     14           MX
# 4       E    NaT           MX
# 5       6     16          NaT
# 6       G     17           MX

# %%
miDataFrame.dropna(subset=['Edades'])
# Out:
#   Nombres Edades Nacionalidad
# 0     NaT     11           MX
# 1       2     12           MX
# 2       C     13           MX
# 3       4     14           MX
# 5       6     16          NaT
# 6       G     17           MX

# %%
miDataFrame.dropna(subset=['Nacionalidad'])
# Out:
#   Nombres Edades Nacionalidad
# 0     NaT     11           MX
# 1       2     12           MX
# 2       C     13           MX
# 3       4     14           MX
# 4       E    NaT           MX
# 6       G     17           MX

# %%
miDiccionario = {
    'Nombres': ['A','B','C','D','E','F','G'],
    'Edades': [10,11,11,13,11,14,11],
    'Nacionalidad': ['MX','MX','MX','MX','MX','MX','MX']
    
}

# %%
test = pd.DataFrame(miDiccionario)

# %%
test
# Out:
#   Nombres  Edades Nacionalidad
# 0       A      10           MX
# 1       B      11           MX
# 2       C      11           MX
# 3       D      13           MX
# 4       E      11           MX
# 5       F      14           MX
# 6       G      11           MX

# %%
    test.drop_duplicates(subset=['Edades'])
# Out:
#   Nombres  Edades Nacionalidad
# 0       A      10           MX
# 1       B      11           MX
# 3       D      13           MX
# 5       F      14           MX

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
# 3  hcY52MFWMDM      17.14.11
# 4  _OXDcGPVAa4      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title  category_id              publish_time  \
# 0            MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1   Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2  El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
# 3                   Casanare           25  2017-11-13T03:47:10.000Z
# 4                      Musas           26  2017-11-13T19:17:48.000Z
#
# ...

# %%
df[df['publish_time']<'2017-12-31']
# Out:
#           video_id trending_date  \
# 0      SbOwzAl9ZfQ      17.14.11
# 1      klOV6Xh-DnI      17.14.11
# 2      6L2ZF7Qzsbk      17.14.11
# 3      hcY52MFWMDM      17.14.11
# 4      _OXDcGPVAa4      17.14.11
# ...            ...           ...
# 20827  rW6CYWRMXQQ      18.28.02
# 21809  RgpoRGq3oBs      18.05.03
# 21893  4qm2zs50Mkc      18.05.03
# 21958          NaN      18.06.03
# 21980  RgpoRGq3oBs      18.06.03
#
#                                                    title  \
# 0                         CapÃ­tulo 12 | MasterChef 2017
# 1      ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2               LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3       Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4               DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
# ...                                                  ...
# 20827                          RUTINA CON BARRA OLIMPICA
# 21809          Every Rolex Tells A Story - James Cameron
# ...
