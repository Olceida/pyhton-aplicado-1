# %%
import requests
import json
from IPython.display import Image

# %%
base_url = 'https://dog.ceo/api/breeds/image/random'

# %%
data = requests.get(base_url)

# %%
data.status_code
# Out:
# 200

# %%
data.ok
# Out:
# True

# %%
data
# Out:
# <Response [200]>

# %%
data.content
# Out:
# b'{"message":"https:\\/\\/images.dog.ceo\\/breeds\\/clumber\\/n02101556_6154.jpg","status":"success"}'

# %%
informacion = json.loads(data.text)
informacion
# Out:
# {'message': 'https://images.dog.ceo/breeds/clumber/n02101556_6154.jpg',
#  'status': 'success'}

# %%
informacion['message']
# Out:
# 'https://images.dog.ceo/breeds/clumber/n02101556_6154.jpg'

# %%
Image(informacion['message'])
