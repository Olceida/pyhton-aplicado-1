# %%
import requests
import json

# %%
artista = input('Artista: ')
limite = input('Limite: ')
base_url = "https://itunes.apple.com/search"
# Out:
# Artista: Lady Gaga
# Limite: 200

# %%
params = {
    'term':artista,
    'limit':limite
}
data = requests.get(base_url, params=params)
data.status_code
# Out:
# 200

# %%
info = data.json()
info
# Out:
# {'resultCount': 200,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 129335935,
#    'collectionId': 1443221533,
#    'trackId': 1443221555,
#    'artistName': 'Wale',
#    'collectionName': 'Attention Deficit (Bonus Track Version)',
#    'trackName': 'Chillin (feat. Lady GaGa)',
#    'collectionCensoredName': 'Attention Deficit (Bonus Track Version)',
#    'trackCensoredName': 'Chillin (feat. Lady GaGa) [Bonus Track]',
#    'artistViewUrl': 'https://music.apple.com/us/artist/wale/129335935?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/chillin-feat-lady-gaga-bonus-track/1443221533?i=1443221555&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/chillin-feat-lady-gaga-bonus-track/1443221533?i=1443221555&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/5b/f5/27/5bf52741-37f1-9c79-c0d1-df5cf26fdf13/mzaf_16079921925300638520.plus.aac.p.m4a',
# ...

# %%
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 200,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 129335935,
#             "collectionId": 1443221533,
#             "trackId": 1443221555,
#             "artistName": "Wale",
#             "collectionName": "Attention Deficit (Bonus Track Version)",
#             "trackName": "Chillin (feat. Lady GaGa)",
#             "collectionCensoredName": "Attention Deficit (Bonus Track Version)",
#             "trackCensoredName": "Chillin (feat. Lady GaGa) [Bonus Track]",
#             "artistViewUrl": "https://music.apple.com/us/artist/wale/129335935?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/chillin-feat-lady-gaga-bonus-track/1443221533?i=1443221555&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/chillin-feat-lady-gaga-bonus-track/1443221533?i=1443221555&uo=4",
# ...

# %%
canciones = info['results']elemento['trackname']
# Out:
# [{'wrapperType': 'track',
#   'kind': 'song',
#   'artistId': 31129163,
#   'collectionId': 96129773,
#   'trackId': 96126846,
#   'artistName': 'Jim Breuer',
#   'collectionName': "Smoke 'n' Breu",
#   'trackName': 'AC/DC (LP Version)',
#   'collectionCensoredName': "Smoke 'n' Breu",
#   'trackCensoredName': 'AC/DC (LP Version)',
#   'artistViewUrl': 'https://music.apple.com/us/artist/jim-breuer/31129163?uo=4',
#   'collectionViewUrl': 'https://music.apple.com/us/album/ac-dc-lp-version/96129773?i=96126846&uo=4',
#   'trackViewUrl': 'https://music.apple.com/us/album/ac-dc-lp-version/96129773?i=96126846&uo=4',
#   'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/19/3b/73/193b73fb-9ab4-6239-3d6b-b2d585e0388e/mzaf_18075235998310476121.plus.aac.p.m4a',
#   'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/c4/91/63/c491637f-d175-0c9b-951a-f06cefdff082/source/30x30bb.jpg',
# ...

# %%
for elemento in info['results']:
    try:
        print(f"{elemento['trackName']} salio en {elemento['releaseDate']}")
    except KeyError:
        pass
# Out:
# Chillin (feat. Lady GaGa) salio en 2009-04-14T12:00:00Z
# Poker Face salio en 2008-08-19T12:00:00Z
# Just Dance (feat. Colby O'Donis) salio en 2008-04-08T12:00:00Z
# 3-Way (The Golden Rule) [feat. Justin Timberlake & Lady Gaga] salio en 2011-05-24T12:00:00Z
# A Star Is Born (2018) salio en 2018-10-05T07:00:00Z
# Paparazzi salio en 2008-08-19T12:00:00Z
# Bad Romance salio en 2009-10-26T12:00:00Z
# December 2, 2014 - Tony Bennett & Lady Gaga salio en 2014-12-02T08:00:00Z
# LoveGame salio en 2008-08-19T12:00:00Z
# Born This Way salio en 2011-02-11T08:00:00Z
# The Edge of Glory salio en 2011-05-09T12:00:00Z
# Alejandro salio en 2009-11-18T08:00:00Z
# Video Phone (Extended Remix) [feat. Lady Gaga] salio en 2008-11-18T08:00:00Z
# Yoü and I salio en 2011-05-23T12:00:00Z
# Telephone (feat. Beyoncé) salio en 2009-11-18T12:00:00Z
# Bad Romance salio en 2009-11-18T08:00:00Z
# Shallow salio en 2018-10-05T12:00:00Z
# Video Phone salio en 2009-11-17T08:00:00Z
# ...
