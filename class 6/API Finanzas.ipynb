# %%
import requests
import json
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
base_url = "https://www.alphavantage.co/query"
function = 'TIME_SERIES_DAILY'
symbol = 'AMD'
outputsize = 'compact'
datatype = 'json'
apikey = 'PON TU KEY AQUI'

params = {
    'function': function,
    'symbol': symbol,
    'outputsize':outputsize,
    'datatype':datatype,
    'apikey':apikey
}

# %%
resultados = requests.get(base_url, params=params)
resultados.status_code
# Out:
# 200

# %%
tesla = resultados.json()
df = pd.DataFrame(tesla['Time Series (Daily)'])
for columna in df.columns:
    df[columna] = pd.to_numeric(df[columna])
df
# Out:
#              2021-08-31    2021-08-30   2021-08-27    2021-08-26   2021-08-25  \
# 1. open    1.112600e+02  1.126100e+02       108.01  1.085700e+02       108.13
# 2. high    1.112600e+02  1.144899e+02       111.78  1.092299e+02       109.91
# 3. low     1.090343e+02  1.112600e+02       107.80  1.068400e+02       107.45
# 4. close   1.107200e+02  1.113200e+02       111.40  1.072700e+02       108.30
# 5. volume  4.926632e+07  5.613047e+07  61030014.00  5.144255e+07  45485504.00
#
#             2021-08-24    2021-08-23   2021-08-20    2021-08-19   2021-08-18  \
# 1. open         109.45  1.052950e+02       104.32  1.033150e+02       107.35
# 2. high         109.61  1.090200e+02       105.98  1.061800e+02       108.07
# 3. low          107.28  1.048600e+02       103.99  1.019750e+02       103.27
# 4. close        107.65  1.087700e+02       104.65  1.037000e+02       103.44
# 5. volume  51239297.00  6.883528e+07  55227562.00  7.111749e+07  79387943.00
#
# ...

# %%
data = [go.Line(x=df.columns, y=df.iloc[1]),go.Line(x=df.columns, y=df.iloc[1]*1.5), go.Line(x=df.columns, y=df.iloc[1]*-1.5)]
layout = go.Layout(title=symbol)

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'
